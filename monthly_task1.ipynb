# %%
import pandas as pd

# %%
import openpyxl
import pandas as pd
from datetime import datetime, date

# Define the file path to your Excel file
file_path = "/content/2024 E-Newsletters.xlsx"

# Load the workbook using openpyxl
wb = openpyxl.load_workbook(file_path, data_only=True)  # Use data_only=True to get cell values instead of formulas

# Get all sheet names
sheet_names = wb.sheetnames

# Sheets to remove
sheets_to_remove = ['Tomorrows Outlook', 'Remaining Full Year Openings', 'Future Outlook', 'Todays Overview']

# Initialize a list to store all data
all_data = []

# Function to check if a cell has a red fill color in the first column
def is_red_fill(cell):
    if cell.column == 1 and cell.fill.fill_type == "solid" and cell.fill.start_color.rgb == "FFFF0000":
        return True
    return False

# Function to check if a cell has red or black font color
def is_coloured_cell(cell):
    if cell.value is not None and cell.font.color and cell.font.color.rgb in ["FFFF0000", "FF000000"]:
        return True
    return False

# Iterate through each sheet
for sheet_name in sheet_names:
    if sheet_name not in sheets_to_remove:
        # Access the sheet
        sheet = wb[sheet_name]

        # Initialize variables for headers and data
        headers = None

        # Iterate through rows
        for i, row in enumerate(sheet.iter_rows()):
            if i == 0:
                # First row as headers
                headers = [cell.value for cell in row[:9]]  # Assuming you want the first 9 columns as headers
            else:
                # Check if the first column contains a valid date
                first_cell = row[0]
                if isinstance(first_cell.value, (datetime, date)):
                    skip_row = False
                    # Check if any cell in the row is red-filled in the first column
                    for cell in row[:1]:  # Checking only the first column
                        if is_red_fill(cell):
                            skip_row = True
                            break

                    if not skip_row:
                        # Iterate through each cell in the row (excluding the first column)
                        for j, cell in enumerate(row[1:9], start=1):
                            if is_coloured_cell(cell):
                                all_data.append({
                                    'Coordinates': cell.coordinate,
                                    'Date': first_cell.value,
                                    'Data': cell.value,
                                    'Column Name': headers[j],
                                    'Sheet Name': sheet_name
                                })

# Create a Pandas DataFrame from all collected data
df = pd.DataFrame(all_data)

# Close the workbook
wb.close()

# Optionally, you can save the DataFrame to a CSV file or further process it as needed
# df.to_csv('output.csv', index=False)

# %%
df
# Out:
#      Coordinates       Date  \
# 0             C4 2024-01-02
# 1             C5 2024-01-03
# 2             C6 2024-01-04
# 3             D6 2024-01-04
# 4             E6 2024-01-04
# ...          ...        ...
# 2648         C95 2024-11-20
# 2649         C97 2024-11-27
# 2650         C99 2024-12-04
# 2651        C100 2024-12-06
# 2652        C101 2024-12-11
#
#                                                    Data    Column Name  \
# 0     American College of Cardiology / ACC (MB) 12.2...  Ad Position 1
# 1     AstraZeneca (Andexxa) (MT/SS)\n12.20.2023\n\nh...  Ad Position 1
# 2     J.D. Power (MB)\n11.30.2023\n\nhttps://cdn.ome...  Ad Position 1
# 3     HWL (MP/CX)(1.3.2023)\n\nhttps://cdn.omeda.com...  Ad Position 2
# 4     BPD (Somer) 12.21.2023\n\nhttps://cdn.omeda.co...  Ad Position 3
# ...                                                 ...            ...
# 2648                                 Merck V116 (AE/SS)  Ad Position 1
# 2649                                 Merck V116 (AE/SS)  Ad Position 1
# 2650                                 Merck V116 (AE/SS)  Ad Position 1
# 2651  Merck VXN (AE/SS)_02.22.2024\n\nhttps://cdn.om...  Ad Position 1
# 2652                                 Merck V116 (AE/SS)  Ad Position 1
#
#                 Sheet Name
# 0                 Hospital
# 1                 Hospital
# 2                 Hospital
# 3                 Hospital
# 4                 Hospital
# ...                    ...
# 2648  Physician Leadership
# 2649  Physician Leadership
# 2650  Physician Leadership
# 2651  Physician Leadership
# 2652  Physician Leadership
#
# [2653 rows x 5 columns]

# %%
import re

def extract_second_url(text):
    urls = re.findall(r'(https?://\S+)', text)
    if len(urls) >= 2:
        return urls[1]  # Select the second URL if available
    elif len(urls) == 1:
        return urls[0]  # Select the first (and only) URL if there's only one
    else:
        return None  # Return None if no URLs are found

# %%
# Extracting required information
df['client manager'] = df['Data'].str.extract(r'\(([^0-9]+)\)')
df['client'] = df['Data'].str.extract(r'^(.*?)\s*\(')
df['date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d').dt.strftime('%m.%d.%Y')
df['sheet_to_a'] = df['Sheet Name'] + ' e-news letter ' + df['Column Name']
df['platform'] = 'Omeda'
df['notes'] = 'standard-date, impressions, clicks, CTR - '+ df['Data'].apply(extract_second_url)

# Selecting required columns
selected_columns = ['Coordinates', 'client manager', 'client', 'date', 'sheet_to_a', 'platform', 'notes']
selected_df = df[selected_columns]

# %%
selected_df
# Out:
#      Coordinates   client manager                                client  \
# 0             C4               MB  American College of Cardiology / ACC
# 1             C5  Andexxa) (MT/SS                           AstraZeneca
# 2             C6               MB                            J.D. Power
# 3             D6            MP/CX                                   HWL
# 4             E6            Somer                                   BPD
# ...          ...              ...                                   ...
# 2648         C95            AE/SS                            Merck V116
# 2649         C97            AE/SS                            Merck V116
# 2650         C99            AE/SS                            Merck V116
# 2651        C100            AE/SS                             Merck VXN
# 2652        C101            AE/SS                            Merck V116
#
#             date                                        sheet_to_a platform  \
# 0     01.02.2024              Hospital e-news letter Ad Position 1    Omeda
# 1     01.03.2024              Hospital e-news letter Ad Position 1    Omeda
# 2     01.04.2024              Hospital e-news letter Ad Position 1    Omeda
# 3     01.04.2024              Hospital e-news letter Ad Position 2    Omeda
# 4     01.04.2024              Hospital e-news letter Ad Position 3    Omeda
# ...          ...                                               ...      ...
# 2648  11.20.2024  Physician Leadership e-news letter Ad Position 1    Omeda
# 2649  11.27.2024  Physician Leadership e-news letter Ad Position 1    Omeda
# 2650  12.04.2024  Physician Leadership e-news letter Ad Position 1    Omeda
# 2651  12.06.2024  Physician Leadership e-news letter Ad Position 1    Omeda
# 2652  12.11.2024  Physician Leadership e-news letter Ad Position 1    Omeda
#
#                                                   notes
# 0     standard-date, impressions, clicks, CTR - http...
# 1     standard-date, impressions, clicks, CTR - http...
# 2     standard-date, impressions, clicks, CTR - http...
# 3     standard-date, impressions, clicks, CTR - http...
# 4     standard-date, impressions, clicks, CTR - http...
# ...                                                 ...
# 2648                                                NaN
# 2649                                                NaN
# 2650                                                NaN
# 2651  standard-date, impressions, clicks, CTR - http...
# 2652                                                NaN
#
# [2653 rows x 7 columns]

# %%
selected_df['date'] = pd.to_datetime(selected_df['date'])  # Convert 'Date' column to datetime format if needed

# Get current month and year
current_month = datetime.now().month
current_year = datetime.now().year

# Filter rows for current month
current_month_data = selected_df[(selected_df['date'].dt.month == current_month) & (selected_df['date'].dt.year == current_year)]

current_month_data
# Out:
# <ipython-input-83-aca8ae9be69d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_df['date'] = pd.to_datetime(selected_df['date'])  # Convert 'Date' column to datetime format if needed
#      Coordinates client manager                    client       date  \
# 284         C157       CX/LE/MP                  T-Mobile 2024-06-01
# 285         D157       CX/LE/MP                  T-Mobile 2024-06-01
# 286         E157       CX/LE/MP                  T-Mobile 2024-06-01
# 287         F157       CX/LE/MP                  T-Mobile 2024-06-01
# 288         C158          Somer                   Staples 2024-06-02
# ...          ...            ...                       ...        ...
# 2606         D51        MT/Jrod  Mayo Clinic Laboratories 2024-06-19
# 2607         E51        MT/Jrod  Mayo Clinic Laboratories 2024-06-19
# 2608         F51        MT/Jrod  Mayo Clinic Laboratories 2024-06-19
# 2609         C53          AE/SS                 Merck VXN 2024-06-26
# 2610         F53          MP/MT                       AMA 2024-06-26
#
#                                             sheet_to_a platform  \
# 284               Hospital e-news letter Ad Position 1    Omeda
# 285               Hospital e-news letter Ad Position 2    Omeda
# 286               Hospital e-news letter Ad Position 3    Omeda
# 287                     Hospital e-news letter Text Ad    Omeda
# 288               Hospital e-news letter Ad Position 1    Omeda
# ...                                                ...      ...
# 2606  Physician Leadership e-news letter Ad Position 2    Omeda
# 2607  Physician Leadership e-news letter Ad Position 3    Omeda
# 2608        Physician Leadership e-news letter Text Ad    Omeda
# 2609  Physician Leadership e-news letter Ad Position 1    Omeda
# 2610        Physician Leadership e-news letter Text Ad    Omeda
#
#                                                   notes
# 284   standard-date, impressions, clicks, CTR - http...
# 285   standard-date, impressions, clicks, CTR - http...
# 286   standard-date, impressions, clicks, CTR - http...
# 287   standard-date, impressions, clicks, CTR - http...
# 288   standard-date, impressions, clicks, CTR - http...
# ...                                                 ...
# 2606  standard-date, impressions, clicks, CTR - http...
# 2607  standard-date, impressions, clicks, CTR - http...
# 2608  standard-date, impressions, clicks, CTR - http...
# 2609  standard-date, impressions, clicks, CTR - http...
# 2610                                                NaN
#
# [271 rows x 7 columns]

# %%
# Save filtered data to Excel
file_path = f"current_month_data_{current_month}_{current_year}.xlsx"
current_month_data.to_excel(file_path, index=False)
